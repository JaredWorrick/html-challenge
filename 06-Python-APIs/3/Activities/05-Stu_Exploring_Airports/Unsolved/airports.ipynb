# %% [markdown]
# # Exploring Airports

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Import API key
from config import geoapify_key

# %% [markdown]
# ## DataFrame Preparation

# %%
# Import cities file as DataFrame
# YOUR CODE HERE
# Out:
#         City
# 0     Sydney
# 1  Melbourne
# 2      Perth
# 3     Cairns
# 4   Adelaide

# %%
# Add columns the airports data we will fetch using the Geoapify API
# Note that we used "" to specify initial entry.
# YOUR CODE HERE
# Out:
#         City Lat Lon Airport Name IATA Name Airport Address Distance Website
# 0     Sydney
# 1  Melbourne
# 2      Perth
# 3     Cairns
# 4   Adelaide

# %% [markdown]
# ## Look for Geographical Coordinates for Each City

# %%
# Define the API parameters
params = {
    "apiKey":geoapify_key,
    "format":"json"
}

# Set the base URL
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Print a message to follow up the airport search
print("Starting airport search")

# Loop through the cities_pd DataFrame and search coordinates for each city
for index, row in cities_pd.iterrows():

    # Get the city's name & add ", Australia" to the string so geoapify finds the correct city
    city = # YOUR CODE HERE

    # Add the current city to the parameters
    params["text"] = # YOUR CODE HERE

    # Make the API request
    response = # YOUR CODE HERE
    
    # Convert reponse to JSON
    response = # YOUR CODE HERE

    # Extract latitude and longitude
    cities_pd.loc[index, "Lat"] = # YOUR CODE HERE
    cities_pd.loc[index, "Lon"] = # YOUR CODE HERE
    
    # Log the search results
    print(f"Coordinates for {city} fetched...")

# Display sample data to confirm that the coordinates appear
# YOUR CODE HERE
# Out:
# Starting airport search
# Coordinates for Sydney fetched...
# Coordinates for Melbourne fetched...
# Coordinates for Perth fetched...
# Coordinates for Cairns fetched...
# Coordinates for Adelaide fetched...
# Coordinates for Gold Coast fetched...
# Coordinates for Townsville fetched...
# Coordinates for Williamtown fetched...
#         City        Lat         Lon Airport Name IATA Name Airport Address  \
# 0     Sydney -33.869844  151.208285
# 1  Melbourne -37.814218  144.963161
# 2      Perth -31.955896   115.86058
# 3     Cairns -16.920666  145.772185
# 4   Adelaide -34.928181  138.599931
#
#   Distance Website
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Retrieve Airports' Information

# %%
# Set parameters to search for airport's details
radius = 50000
params = {
    "categories":"airport",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the airport search
print("Starting airport details search")

# Iterate through the types_df DataFrame
for index, row in cities_pd.iterrows():
    
    # Get the city's name
    city = # YOUR CODE HERE
    
    # Get latitude, longitude from the DataFrame
    latitude = # YOUR CODE HERE
    longitude = # YOUR CODE HERE
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
           
    # Make an API request using the params dictionary
    response = # YOUR CODE HERE
        
    # Convert the API response to JSON format
    response = # YOUR CODE HERE
    
    # Grab the first airport from the results and store the details in the DataFrame
    try:
        cities_pd.loc[index, "Airport Name"] = # YOUR CODE HERE
        cities_pd.loc[index, "IATA Name"] = # YOUR CODE HERE
        cities_pd.loc[index, "Airport Address"] = # YOUR CODE HERE
        cities_pd.loc[index, "Distance"] = # YOUR CODE HERE
        cities_pd.loc[index, "Website"] = # YOUR CODE HERE
    except KeyError as e:
        # If no airport is found, log the error.
        print(f"{e.args[0]} not found for {cities_pd.loc[index, 'Airport Name']}")
        
    # Log the search results
    print(f"nearest airport from {city}: {cities_pd.loc[index, 'Airport Name']}")

# Display sample data
# YOUR CODE HERE
# Out:
# Starting airport details search
# nearest airport fron Sydney: Sydney (Kingsford Smith) Airport
# nearest airport fron Melbourne: Essendon Fields Airport
# nearest airport fron Perth: Perth Airport
# website not found for Cairns Airport
# nearest airport fron Cairns: Cairns Airport
# nearest airport fron Adelaide: Adelaide Airport
# nearest airport fron Gold Coast: Gold Coast Airport
# nearest airport fron Townsville: Townsville Airport
# nearest airport fron Williamtown: Newcastle Airport
#           City        Lat         Lon                      Airport Name  \
# 0       Sydney -33.869844  151.208285  Sydney (Kingsford Smith) Airport
# 1    Melbourne -37.814218  144.963161           Essendon Fields Airport
# 2        Perth -31.955896   115.86058                     Perth Airport
# 3       Cairns -16.920666  145.772185                    Cairns Airport
# 4     Adelaide -34.928181  138.599931                  Adelaide Airport
# 5   Gold Coast -28.002373  153.414599                Gold Coast Airport
# 6   Townsville -19.256939  146.823954                Townsville Airport
# 7  Williamtown    -32.815  151.842778                 Newcastle Airport
#
#   IATA Name                                    Airport Address Distance  \
# 0       SYD        Eleventh Street, Mascot NSW 2020, Australia     6742
# 1       MEB  72 Hargrave Avenue, Essendon Fields VIC 3041, ...     9980
# 2       PER                 Hay Road, Ascot WA 6104, Australia     8775
# 3       CNS      Sheridan Street, Aeroglen QLD 4870, Australia     3461
# 4       ADL                Adelaide Airport SA 5950, Australia     4898
# 5       OOL         Cahill Street, Bilinga QLD 4225, Australia    18807
# 6       TSV         Meenan Street, Garbutt QLD 4812, Australia     4711
# 7       NTL    55 Slades Road, Williamtown NSW 2318, Australia      620
#
#                                  Website
# 0      https://www.sydneyairport.com.au/
# 1                 https://www.ef.com.au/
# 2       https://www.perthairport.com.au/
# 3
# 4    https://www.adelaideairport.com.au/
# 5   https://www.goldcoastairport.com.au/
# 6  https://www.townsvilleairport.com.au/
# 7    https://www.newcastleairport.com.au

# %%
# Save Data to csv
# YOUR CODE HERE
